# %%
# !ls provided_data
# Out:
# 'IPEDS Variables for Data Selection.pdf'
# 'Problem C - CollegeScorecardDataDictionary-09-08-2015.xlsx'
# 'Problem C - IPEDS UID for Potential Candidate Schools.xlsx'
# 'Problem C - Most Recent Cohorts Data (Scorecard Elements).xlsx'

# %%
import pandas

# %%
candidates = pandas.read_excel('provided_data/Problem C - IPEDS UID for Potential Candidate Schools.xlsx')
candidates
# Out:
#       UNITID                                             INSTNM  \
# 0     110486            California State University-Bakersfield
# 1     110635                  University of California-Berkeley
# 2     110918                       California Christian College
# 3     111188                        California Maritime Academy
# 4     111920                                     Chabot College
# 5     111939                                    Chaffey College
# 6     128498                            Albertus Magnus College
# 7     128902                                Connecticut College
# 8     130004                          Norwalk Community College
# 9     144193   City Colleges of Chicago-Richard J Daley College
# 10    144944                            Elgin Community College
# 11    145497                         Hebrew Theological College
# 12    145646                       Illinois Wesleyan University
# 13    145682                           Illinois Central College
# ...

# %%
data = pandas.read_excel('provided_data/Problem C - Most Recent Cohorts Data (Scorecard Elements).xlsx')
data
# Out:
#         UNITID    OPEID  opeid6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# 5       100751   105100    1051
# 6       100760   100700    1007
# 7       100812   100800    1008
# 8       100830   831000    8310
# 9       100858   100900    1009
# 10      100937   101200    1012
# 11      101028  1218200   12182
# 12      101073  1055400   10554
# 13      101116  1303906   13039
# 14      101143   101500    1015
# 15      101161   106000    1060
# 16      101189   100300    1003
# 17      101240   101700    1017
# 18      101277  4187200   41872
# 19      101286   101800    1018
# 20      101295   787100    7871
# 21      101301   569900    5699
# 22      101365   962107    9621
# 23      101435   101900    1019
# 24      101453  2199700   21997
# 25      101462   526000    5260
# 26      101480   102000    1020
# 27      101499   102100    1021
# ...

# %%
variables = pandas.read_excel('provided_data/Problem C - CollegeScorecardDataDictionary-09-08-2015.xlsx')
variables
# Out:
#                                    NAME OF DATA ELEMENT dev-category  \
# 0                               Unit ID for institution         root
# 1                        8-digit OPE ID for institution         root
# 2                        6-digit OPE ID for institution         root
# 3                                      Institution name       school
# 4                                                  City       school
# 5                                        State postcode       school
# 6                                              ZIP code       school
# 7                            Accreditor for institution       school
# 8                        URL for institution's homepage       school
# 9            URL for institution's net price calculator       school
# 10       Predominant degree awarded (recoded 0s and 4s)       school
# 11                                 Flag for main campus       school
# 12                                                  NaN       school
# ...
